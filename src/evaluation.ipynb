# %%
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# %%
from task_config import *
# configs_list = [ZeroFlatConfig1, ZeroFlatConfig2, FewFlatConfig1, FewFlatConfig2]
configs_list = [
    ZeroFlatConfig1, ZeroFlatConfig2, 
    FewFlatConfig1, FewFlatConfig2, 
    ZeroHierConfig1, ZeroHierConfig2
]

# %%
def extract_claim_subclaim(code):
    if pd.isna(code) or code == '-1':
        return -1, -1
    try:
        claim, _ = map(int, code.split('_'))
        return claim, code
    except Exception:
        return -1, -1

# %%
def calculate_metrics(y_true, y_pred):
    if y_true.unique()[0] == "0_0":
        print("Here")
    TP = (y_true == y_pred).sum()

    total_pred = len(y_pred)
    total_true = len(y_true)

    precision = TP / total_pred
    recall = TP / total_true
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

    print(f"Precision: {precision:.4f} | Recall: {recall:.4f} | F1 Score: {f1:.4f}")
    return precision, recall, f1

# %%
def evaluate_predictions(df):
    metrics = []

    df[['true_claim', 'true_subclaim']] = df['sub_claim_code'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))
    df[['pred_claim', 'pred_subclaim']] = df['prediction'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))

    total = len(df)
    invalid = len(df[df['pred_subclaim'] == -1])
    valid = total - invalid
    
    metrics.append({
        "Category": "Summary",
        "Precision": None,
        "Recall": None,
        "F1 Score": None,
        "Support": f"{valid}/{total} ({valid / total:.1%} valid)"
    })

    # Filter valid examples only
    valid_df = df[(df['pred_subclaim'] != -1) & (df['true_subclaim'] != -1)]

    # ---------- Overall Metrics ----------
    precision, recall, f1 = calculate_metrics(valid_df['true_subclaim'], valid_df['pred_subclaim'])
    metrics.append({
            "Category": "All Sub-claims",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
    })

    # print("\n--- Overall Claim Classification ---")
    precision, recall, f1 = calculate_metrics(valid_df['true_claim'], valid_df['pred_claim'])
    metrics.append({
            "Category": "All Claims",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
    })

    # ---------- Per-Claim Category ----------
    for claim in sorted(valid_df['true_claim'].unique()):
        subset = valid_df[valid_df['true_claim'] == claim]
        precision, recall, f1 = calculate_metrics(subset['true_claim'], subset['pred_claim'])
        metrics.append({
            "Category": f"Claim {claim}",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
        })

    # ---------- Per Sub-Claim Category ----------
    for subclaim in sorted(valid_df['true_subclaim'].unique()):

        subset = valid_df[valid_df['true_subclaim'] == subclaim][["true_subclaim", "pred_subclaim"]]

        # if "0_0" == subclaim:
        #     print(subset.head(100))
        #     print("HERE")
        #     calculate_metrics(subset['true_subclaim'], subset['pred_subclaim'])
        #     return None
        precision, recall, f1 = calculate_metrics(subset['true_subclaim'], subset['pred_subclaim'])
        metrics.append({
            "Category": f"Sub-claim {subclaim}",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
        })

    return pd.DataFrame(metrics)

# %%
def print_statistics(df):

    df[['true_claim', 'true_subclaim']] = df['sub_claim_code'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))
    df[['pred_claim', 'pred_subclaim']] = df['prediction'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))

    total = len(df)
    invalid = len(df[df['pred_subclaim'] == -1])
    valid = total - invalid
    
    valid_df = df[(df['pred_subclaim'] != -1) & (df['true_subclaim'] != -1)]

    for claim in sorted(valid_df['true_claim'].unique()):
        subset = valid_df[valid_df['true_claim'] == claim]
        print(f"Claim: {claim}: {len(subset)}")
        
    for subclaim in sorted(valid_df['true_subclaim'].unique()):
        subset = valid_df[valid_df['true_subclaim'] == subclaim]
        print(f"Sublaim: {subclaim}: {len(subset)}")

# %%
combined_df = None
printed_stats_test = False
printed_stats_val = False

for task_config in configs_list:
    result_dir = task_config.result_dir.format("val" if task_config.val_mode else "test") 
    result_path = f"{result_dir}/{task_config.id}.csv"
    df = pd.read_csv(result_path)

    if task_config.val_mode and not printed_stats_val:
        print_statistics(df)
        printed_stats_val = True
    if not task_config.val_mode and not printed_stats_test:
        print_statistics(df)
        printed_stats_test = True
    
    metrics_df = evaluate_predictions(df)
    metrics_df.insert(0, 'Task', task_config.name)
    if combined_df is None:
        combined_df = metrics_df
    else:
        combined_df = pd.concat([combined_df, metrics_df], ignore_index=True)
# Out:
# Claim: 0: 1730
# Claim: 1: 242
# Claim: 2: 168
# Claim: 3: 119
# Claim: 4: 169
# Claim: 5: 215
# Sublaim: 0_0: 1730
# Sublaim: 1_1: 48
# Sublaim: 1_2: 21
# Sublaim: 1_3: 30
# Sublaim: 1_4: 68
# Sublaim: 1_6: 12
# Sublaim: 1_7: 63
# Sublaim: 2_1: 122
# Sublaim: 2_3: 46
# Sublaim: 3_1: 25
# Sublaim: 3_2: 49
# Sublaim: 3_3: 45
# Sublaim: 4_1: 62
# Sublaim: 4_2: 34
# Sublaim: 4_4: 38
# Sublaim: 4_5: 35
# Sublaim: 5_1: 150
# Sublaim: 5_2: 65
# Precision: 0.6387 | Recall: 0.6387 | F1 Score: 0.6387
# Precision: 0.6950 | Recall: 0.6950 | F1 Score: 0.6950
# Precision: 0.8676 | Recall: 0.8676 | F1 Score: 0.8676
# Precision: 0.4793 | Recall: 0.4793 | F1 Score: 0.4793
# Precision: 0.3750 | Recall: 0.3750 | F1 Score: 0.3750
# Precision: 0.3950 | Recall: 0.3950 | F1 Score: 0.3950
# Precision: 0.4615 | Recall: 0.4615 | F1 Score: 0.4615
# Precision: 0.1488 | Recall: 0.1488 | F1 Score: 0.1488
# Here
# Precision: 0.8676 | Recall: 0.8676 | F1 Score: 0.8676
# Precision: 0.1667 | Recall: 0.1667 | F1 Score: 0.1667
# Precision: 0.8095 | Recall: 0.8095 | F1 Score: 0.8095
# Precision: 0.6667 | Recall: 0.6667 | F1 Score: 0.6667
# Precision: 0.3971 | Recall: 0.3971 | F1 Score: 0.3971
# Precision: 0.6667 | Recall: 0.6667 | F1 Score: 0.6667
# Precision: 0.1587 | Recall: 0.1587 | F1 Score: 0.1587
# Precision: 0.2869 | Recall: 0.2869 | F1 Score: 0.2869
# Precision: 0.0870 | Recall: 0.0870 | F1 Score: 0.0870
# Precision: 0.1200 | Recall: 0.1200 | F1 Score: 0.1200
# Precision: 0.2857 | Recall: 0.2857 | F1 Score: 0.2857
# Precision: 0.0889 | Recall: 0.0889 | F1 Score: 0.0889
# Precision: 0.1935 | Recall: 0.1935 | F1 Score: 0.1935
# Precision: 0.3824 | Recall: 0.3824 | F1 Score: 0.3824
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0857 | Recall: 0.0857 | F1 Score: 0.0857
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.1385 | Recall: 0.1385 | F1 Score: 0.1385
# Claim: 0: 1788
# Claim: 1: 184
# Claim: 2: 124
# Claim: 3: 95
# Claim: 4: 102
# Claim: 5: 257
# Sublaim: 0_0: 1788
# Sublaim: 1_1: 37
# Sublaim: 1_2: 16
# Sublaim: 1_3: 25
# Sublaim: 1_4: 52
# Sublaim: 1_6: 10
# Sublaim: 1_7: 44
# Sublaim: 2_1: 87
# Sublaim: 2_3: 37
# Sublaim: 3_1: 21
# Sublaim: 3_2: 38
# Sublaim: 3_3: 36
# Sublaim: 4_1: 35
# Sublaim: 4_2: 21
# Sublaim: 4_4: 26
# Sublaim: 4_5: 20
# Sublaim: 5_1: 146
# Sublaim: 5_2: 111
# Here
# Precision: 0.6427 | Recall: 0.6427 | F1 Score: 0.6427
# Precision: 0.6925 | Recall: 0.6925 | F1 Score: 0.6925
# Precision: 0.8272 | Recall: 0.8272 | F1 Score: 0.8272
# Precision: 0.5326 | Recall: 0.5326 | F1 Score: 0.5326
# Precision: 0.4032 | Recall: 0.4032 | F1 Score: 0.4032
# Precision: 0.4632 | Recall: 0.4632 | F1 Score: 0.4632
# Precision: 0.4608 | Recall: 0.4608 | F1 Score: 0.4608
# Precision: 0.1868 | Recall: 0.1868 | F1 Score: 0.1868
# Here
# Precision: 0.8272 | Recall: 0.8272 | F1 Score: 0.8272
# Precision: 0.0811 | Recall: 0.0811 | F1 Score: 0.0811
# Precision: 0.6250 | Recall: 0.6250 | F1 Score: 0.6250
# Precision: 0.6800 | Recall: 0.6800 | F1 Score: 0.6800
# Precision: 0.3462 | Recall: 0.3462 | F1 Score: 0.3462
# Precision: 0.5000 | Recall: 0.5000 | F1 Score: 0.5000
# Precision: 0.2727 | Recall: 0.2727 | F1 Score: 0.2727
# Precision: 0.3333 | Recall: 0.3333 | F1 Score: 0.3333
# Precision: 0.1081 | Recall: 0.1081 | F1 Score: 0.1081
# Precision: 0.1905 | Recall: 0.1905 | F1 Score: 0.1905
# Precision: 0.3158 | Recall: 0.3158 | F1 Score: 0.3158
# Precision: 0.1667 | Recall: 0.1667 | F1 Score: 0.1667
# Precision: 0.2857 | Recall: 0.2857 | F1 Score: 0.2857
# Precision: 0.4762 | Recall: 0.4762 | F1 Score: 0.4762
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0500 | Recall: 0.0500 | F1 Score: 0.0500
# Precision: 0.0137 | Recall: 0.0137 | F1 Score: 0.0137
# Precision: 0.1532 | Recall: 0.1532 | F1 Score: 0.1532
# Here
# Precision: 0.6261 | Recall: 0.6261 | F1 Score: 0.6261
# Precision: 0.6773 | Recall: 0.6773 | F1 Score: 0.6773
# Precision: 0.8820 | Recall: 0.8820 | F1 Score: 0.8820
# Precision: 0.4884 | Recall: 0.4884 | F1 Score: 0.4884
# Precision: 0.3810 | Recall: 0.3810 | F1 Score: 0.3810
# Precision: 0.3832 | Recall: 0.3832 | F1 Score: 0.3832
# Precision: 0.3733 | Recall: 0.3733 | F1 Score: 0.3733
# Precision: 0.1653 | Recall: 0.1653 | F1 Score: 0.1653
# Here
# Precision: 0.8820 | Recall: 0.8820 | F1 Score: 0.8820
# Precision: 0.1905 | Recall: 0.1905 | F1 Score: 0.1905
# Precision: 0.8500 | Recall: 0.8500 | F1 Score: 0.8500
# Precision: 0.7143 | Recall: 0.7143 | F1 Score: 0.7143
# Precision: 0.3898 | Recall: 0.3898 | F1 Score: 0.3898
# Precision: 0.5714 | Recall: 0.5714 | F1 Score: 0.5714
# Precision: 0.1525 | Recall: 0.1525 | F1 Score: 0.1525
# Precision: 0.2252 | Recall: 0.2252 | F1 Score: 0.2252
# Precision: 0.1389 | Recall: 0.1389 | F1 Score: 0.1389
# Precision: 0.1364 | Recall: 0.1364 | F1 Score: 0.1364
# Precision: 0.2558 | Recall: 0.2558 | F1 Score: 0.2558
# Precision: 0.1190 | Recall: 0.1190 | F1 Score: 0.1190
# Precision: 0.1698 | Recall: 0.1698 | F1 Score: 0.1698
# Precision: 0.3226 | Recall: 0.3226 | F1 Score: 0.3226
# Precision: 0.0312 | Recall: 0.0312 | F1 Score: 0.0312
# Precision: 0.1176 | Recall: 0.1176 | F1 Score: 0.1176
# Precision: 0.0214 | Recall: 0.0214 | F1 Score: 0.0214
# Precision: 0.1307 | Recall: 0.1307 | F1 Score: 0.1307
# Here
# Precision: 0.6711 | Recall: 0.6711 | F1 Score: 0.6711
# Precision: 0.7146 | Recall: 0.7146 | F1 Score: 0.7146
# Precision: 0.8549 | Recall: 0.8549 | F1 Score: 0.8549
# Precision: 0.5636 | Recall: 0.5636 | F1 Score: 0.5636
# Precision: 0.4206 | Recall: 0.4206 | F1 Score: 0.4206
# Precision: 0.3690 | Recall: 0.3690 | F1 Score: 0.3690
# Precision: 0.3913 | Recall: 0.3913 | F1 Score: 0.3913
# Precision: 0.1593 | Recall: 0.1593 | F1 Score: 0.1593
# Here
# Precision: 0.8549 | Recall: 0.8549 | F1 Score: 0.8549
# Precision: 0.1212 | Recall: 0.1212 | F1 Score: 0.1212
# Precision: 0.6250 | Recall: 0.6250 | F1 Score: 0.6250
# Precision: 0.6800 | Recall: 0.6800 | F1 Score: 0.6800
# Precision: 0.4091 | Recall: 0.4091 | F1 Score: 0.4091
# Precision: 0.6250 | Recall: 0.6250 | F1 Score: 0.6250
# Precision: 0.2308 | Recall: 0.2308 | F1 Score: 0.2308
# Precision: 0.2840 | Recall: 0.2840 | F1 Score: 0.2840
# Precision: 0.1538 | Recall: 0.1538 | F1 Score: 0.1538
# Precision: 0.0667 | Recall: 0.0667 | F1 Score: 0.0667
# Precision: 0.2778 | Recall: 0.2778 | F1 Score: 0.2778
# Precision: 0.1515 | Recall: 0.1515 | F1 Score: 0.1515
# Precision: 0.2581 | Recall: 0.2581 | F1 Score: 0.2581
# Precision: 0.3125 | Recall: 0.3125 | F1 Score: 0.3125
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.1053 | Recall: 0.1053 | F1 Score: 0.1053
# Precision: 0.0156 | Recall: 0.0156 | F1 Score: 0.0156
# Precision: 0.1429 | Recall: 0.1429 | F1 Score: 0.1429
# Precision: 0.6234 | Recall: 0.6234 | F1 Score: 0.6234
# Precision: 0.6336 | Recall: 0.6336 | F1 Score: 0.6336
# Precision: 0.9789 | Recall: 0.9789 | F1 Score: 0.9789
# Precision: 0.0415 | Recall: 0.0415 | F1 Score: 0.0415
# Precision: 0.0132 | Recall: 0.0132 | F1 Score: 0.0132
# Precision: 0.0097 | Recall: 0.0097 | F1 Score: 0.0097
# Precision: 0.0069 | Recall: 0.0069 | F1 Score: 0.0069
# Precision: 0.1508 | Recall: 0.1508 | F1 Score: 0.1508
# Here
# Precision: 0.9789 | Recall: 0.9789 | F1 Score: 0.9789
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.1765 | Recall: 0.1765 | F1 Score: 0.1765
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0714 | Recall: 0.0714 | F1 Score: 0.0714
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0513 | Recall: 0.0513 | F1 Score: 0.0513
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0303 | Recall: 0.0303 | F1 Score: 0.0303
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0533 | Recall: 0.0533 | F1 Score: 0.0533
# Precision: 0.1103 | Recall: 0.1103 | F1 Score: 0.1103
# Here
# Precision: 0.7025 | Recall: 0.7025 | F1 Score: 0.7025
# Precision: 0.7075 | Recall: 0.7075 | F1 Score: 0.7075
# Precision: 0.9752 | Recall: 0.9752 | F1 Score: 0.9752
# Precision: 0.0432 | Recall: 0.0432 | F1 Score: 0.0432
# Precision: 0.0093 | Recall: 0.0093 | F1 Score: 0.0093
# Precision: 0.0135 | Recall: 0.0135 | F1 Score: 0.0135
# Precision: 0.0111 | Recall: 0.0111 | F1 Score: 0.0111
# Precision: 0.1140 | Recall: 0.1140 | F1 Score: 0.1140
# Here
# Precision: 0.9752 | Recall: 0.9752 | F1 Score: 0.9752
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0667 | Recall: 0.0667 | F1 Score: 0.0667
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0667 | Recall: 0.0667 | F1 Score: 0.0667
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0137 | Recall: 0.0137 | F1 Score: 0.0137
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0312 | Recall: 0.0312 | F1 Score: 0.0312
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0000 | Recall: 0.0000 | F1 Score: 0.0000
# Precision: 0.0270 | Recall: 0.0270 | F1 Score: 0.0270
# Precision: 0.1463 | Recall: 0.1463 | F1 Score: 0.1463

# %%
import pandas as pd

# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)

combined_df.head(len(combined_df))
# Out:
#                                       Task        Category  Precision  \
# 0                     ClaimCheck::ZeroFlat         Summary        NaN
# 1                     ClaimCheck::ZeroFlat  All Sub-claims   0.638668
# 2                     ClaimCheck::ZeroFlat      All Claims   0.695044
# 3                     ClaimCheck::ZeroFlat         Claim 0   0.867630
# 4                     ClaimCheck::ZeroFlat         Claim 1   0.479339
# 5                     ClaimCheck::ZeroFlat         Claim 2   0.375000
# 6                     ClaimCheck::ZeroFlat         Claim 3   0.394958
# 7                     ClaimCheck::ZeroFlat         Claim 4   0.461538
# 8                     ClaimCheck::ZeroFlat         Claim 5   0.148837
# 9                     ClaimCheck::ZeroFlat   Sub-claim 0_0   0.867630
# 10                    ClaimCheck::ZeroFlat   Sub-claim 1_1   0.166667
# 11                    ClaimCheck::ZeroFlat   Sub-claim 1_2   0.809524
# 12                    ClaimCheck::ZeroFlat   Sub-claim 1_3   0.666667
# 13                    ClaimCheck::ZeroFlat   Sub-claim 1_4   0.397059
# 14                    ClaimCheck::ZeroFlat   Sub-claim 1_6   0.666667
# 15                    ClaimCheck::ZeroFlat   Sub-claim 1_7   0.158730
# 16                    ClaimCheck::ZeroFlat   Sub-claim 2_1   0.286885
# 17                    ClaimCheck::ZeroFlat   Sub-claim 2_3   0.086957
# 18                    ClaimCheck::ZeroFlat   Sub-claim 3_1   0.120000
# 19                    ClaimCheck::ZeroFlat   Sub-claim 3_2   0.285714
# 20                    ClaimCheck::ZeroFlat   Sub-claim 3_3   0.088889
# 21                    ClaimCheck::ZeroFlat   Sub-claim 4_1   0.193548
# 22                    ClaimCheck::ZeroFlat   Sub-claim 4_2   0.382353
# 23                    ClaimCheck::ZeroFlat   Sub-claim 4_4   0.000000
# 24                    ClaimCheck::ZeroFlat   Sub-claim 4_5   0.085714
# 25                    ClaimCheck::ZeroFlat   Sub-claim 5_1   0.000000
# 26                    ClaimCheck::ZeroFlat   Sub-claim 5_2   0.138462
# 27               ClaimCheck::ZeroFlat::Val         Summary        NaN
# 28               ClaimCheck::ZeroFlat::Val  All Sub-claims   0.642745
# 29               ClaimCheck::ZeroFlat::Val      All Claims   0.692549
# 30               ClaimCheck::ZeroFlat::Val         Claim 0   0.827181
# 31               ClaimCheck::ZeroFlat::Val         Claim 1   0.532609
# 32               ClaimCheck::ZeroFlat::Val         Claim 2   0.403226
# 33               ClaimCheck::ZeroFlat::Val         Claim 3   0.463158
# 34               ClaimCheck::ZeroFlat::Val         Claim 4   0.460784
# 35               ClaimCheck::ZeroFlat::Val         Claim 5   0.186770
# 36               ClaimCheck::ZeroFlat::Val   Sub-claim 0_0   0.827181
# 37               ClaimCheck::ZeroFlat::Val   Sub-claim 1_1   0.081081
# 38               ClaimCheck::ZeroFlat::Val   Sub-claim 1_2   0.625000
# 39               ClaimCheck::ZeroFlat::Val   Sub-claim 1_3   0.680000
# 40               ClaimCheck::ZeroFlat::Val   Sub-claim 1_4   0.346154
# 41               ClaimCheck::ZeroFlat::Val   Sub-claim 1_6   0.500000
# 42               ClaimCheck::ZeroFlat::Val   Sub-claim 1_7   0.272727
# 43               ClaimCheck::ZeroFlat::Val   Sub-claim 2_1   0.333333
# 44               ClaimCheck::ZeroFlat::Val   Sub-claim 2_3   0.108108
# 45               ClaimCheck::ZeroFlat::Val   Sub-claim 3_1   0.190476
# 46               ClaimCheck::ZeroFlat::Val   Sub-claim 3_2   0.315789
# 47               ClaimCheck::ZeroFlat::Val   Sub-claim 3_3   0.166667
# 48               ClaimCheck::ZeroFlat::Val   Sub-claim 4_1   0.285714
# 49               ClaimCheck::ZeroFlat::Val   Sub-claim 4_2   0.476190
# 50               ClaimCheck::ZeroFlat::Val   Sub-claim 4_4   0.000000
# 51               ClaimCheck::ZeroFlat::Val   Sub-claim 4_5   0.050000
# 52               ClaimCheck::ZeroFlat::Val   Sub-claim 5_1   0.013699
# 53               ClaimCheck::ZeroFlat::Val   Sub-claim 5_2   0.153153
# 54        ClaimCheck::FewShotFlat::Similar         Summary        NaN
# 55        ClaimCheck::FewShotFlat::Similar  All Sub-claims   0.626074
# 56        ClaimCheck::FewShotFlat::Similar      All Claims   0.677251
# 57        ClaimCheck::FewShotFlat::Similar         Claim 0   0.882006
# 58        ClaimCheck::FewShotFlat::Similar         Claim 1   0.488372
# 59        ClaimCheck::FewShotFlat::Similar         Claim 2   0.380952
# 60        ClaimCheck::FewShotFlat::Similar         Claim 3   0.383178
# 61        ClaimCheck::FewShotFlat::Similar         Claim 4   0.373333
# 62        ClaimCheck::FewShotFlat::Similar         Claim 5   0.165289
# 63        ClaimCheck::FewShotFlat::Similar   Sub-claim 0_0   0.882006
# 64        ClaimCheck::FewShotFlat::Similar   Sub-claim 1_1   0.190476
# 65        ClaimCheck::FewShotFlat::Similar   Sub-claim 1_2   0.850000
# 66        ClaimCheck::FewShotFlat::Similar   Sub-claim 1_3   0.714286
# 67        ClaimCheck::FewShotFlat::Similar   Sub-claim 1_4   0.389831
# 68        ClaimCheck::FewShotFlat::Similar   Sub-claim 1_6   0.571429
# 69        ClaimCheck::FewShotFlat::Similar   Sub-claim 1_7   0.152542
# 70        ClaimCheck::FewShotFlat::Similar   Sub-claim 2_1   0.225225
# 71        ClaimCheck::FewShotFlat::Similar   Sub-claim 2_3   0.138889
# 72        ClaimCheck::FewShotFlat::Similar   Sub-claim 3_1   0.136364
# 73        ClaimCheck::FewShotFlat::Similar   Sub-claim 3_2   0.255814
# 74        ClaimCheck::FewShotFlat::Similar   Sub-claim 3_3   0.119048
# 75        ClaimCheck::FewShotFlat::Similar   Sub-claim 4_1   0.169811
# 76        ClaimCheck::FewShotFlat::Similar   Sub-claim 4_2   0.322581
# 77        ClaimCheck::FewShotFlat::Similar   Sub-claim 4_4   0.031250
# 78        ClaimCheck::FewShotFlat::Similar   Sub-claim 4_5   0.117647
# 79        ClaimCheck::FewShotFlat::Similar   Sub-claim 5_1   0.021390
# 80        ClaimCheck::FewShotFlat::Similar   Sub-claim 5_2   0.130682
# 81   ClaimCheck::FewShotFlat::Similar::Val         Summary        NaN
# 82   ClaimCheck::FewShotFlat::Similar::Val  All Sub-claims   0.671130
# 83   ClaimCheck::FewShotFlat::Similar::Val      All Claims   0.714644
# 84   ClaimCheck::FewShotFlat::Similar::Val         Claim 0   0.854895
# 85   ClaimCheck::FewShotFlat::Similar::Val         Claim 1   0.563636
# 86   ClaimCheck::FewShotFlat::Similar::Val         Claim 2   0.420561
# 87   ClaimCheck::FewShotFlat::Similar::Val         Claim 3   0.369048
# 88   ClaimCheck::FewShotFlat::Similar::Val         Claim 4   0.391304
# 89   ClaimCheck::FewShotFlat::Similar::Val         Claim 5   0.159292
# 90   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 0_0   0.854895
# 91   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_1   0.121212
# 92   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_2   0.625000
# 93   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_3   0.680000
# 94   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_4   0.409091
# 95   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_6   0.625000
# 96   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_7   0.230769
# 97   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 2_1   0.283951
# 98   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 2_3   0.153846
# 99   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 3_1   0.066667
# 100  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 3_2   0.277778
# 101  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 3_3   0.151515
# 102  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_1   0.258065
# 103  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_2   0.312500
# 104  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_4   0.000000
# 105  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_5   0.105263
# 106  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 5_1   0.015625
# 107  ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 5_2   0.142857
# 108                   ClaimCheck::ZeroHier         Summary        NaN
# 109                   ClaimCheck::ZeroHier  All Sub-claims   0.623361
# 110                   ClaimCheck::ZeroHier      All Claims   0.633607
# 111                   ClaimCheck::ZeroHier         Claim 0   0.978934
# 112                   ClaimCheck::ZeroHier         Claim 1   0.041475
# 113                   ClaimCheck::ZeroHier         Claim 2   0.013245
# 114                   ClaimCheck::ZeroHier         Claim 3   0.009709
# 115                   ClaimCheck::ZeroHier         Claim 4   0.006897
# 116                   ClaimCheck::ZeroHier         Claim 5   0.150820
# 117                   ClaimCheck::ZeroHier   Sub-claim 0_0   0.978934
# 118                   ClaimCheck::ZeroHier   Sub-claim 1_1   0.000000
# 119                   ClaimCheck::ZeroHier   Sub-claim 1_2   0.176471
# 120                   ClaimCheck::ZeroHier   Sub-claim 1_3   0.000000
# 121                   ClaimCheck::ZeroHier   Sub-claim 1_4   0.071429
# 122                   ClaimCheck::ZeroHier   Sub-claim 1_6   0.000000
# 123                   ClaimCheck::ZeroHier   Sub-claim 1_7   0.000000
# 124                   ClaimCheck::ZeroHier   Sub-claim 2_1   0.000000
# 125                   ClaimCheck::ZeroHier   Sub-claim 2_3   0.051282
# 126                   ClaimCheck::ZeroHier   Sub-claim 3_1   0.000000
# 127                   ClaimCheck::ZeroHier   Sub-claim 3_2   0.000000
# 128                   ClaimCheck::ZeroHier   Sub-claim 3_3   0.000000
# 129                   ClaimCheck::ZeroHier   Sub-claim 4_1   0.000000
# 130                   ClaimCheck::ZeroHier   Sub-claim 4_2   0.000000
# 131                   ClaimCheck::ZeroHier   Sub-claim 4_4   0.030303
# 132                   ClaimCheck::ZeroHier   Sub-claim 4_5   0.000000
# 133                   ClaimCheck::ZeroHier   Sub-claim 5_1   0.053254
# 134                   ClaimCheck::ZeroHier   Sub-claim 5_2   0.110294
# 135              ClaimCheck::ZeroHier::Val         Summary        NaN
# 136              ClaimCheck::ZeroHier::Val  All Sub-claims   0.702453
# 137              ClaimCheck::ZeroHier::Val      All Claims   0.707543
# 138              ClaimCheck::ZeroHier::Val         Claim 0   0.975244
# 139              ClaimCheck::ZeroHier::Val         Claim 1   0.043210
# 140              ClaimCheck::ZeroHier::Val         Claim 2   0.009346
# 141              ClaimCheck::ZeroHier::Val         Claim 3   0.013514
# 142              ClaimCheck::ZeroHier::Val         Claim 4   0.011111
# 143              ClaimCheck::ZeroHier::Val         Claim 5   0.113990
# 144              ClaimCheck::ZeroHier::Val   Sub-claim 0_0   0.975244
# 145              ClaimCheck::ZeroHier::Val   Sub-claim 1_1   0.000000
# 146              ClaimCheck::ZeroHier::Val   Sub-claim 1_2   0.066667
# 147              ClaimCheck::ZeroHier::Val   Sub-claim 1_3   0.000000
# 148              ClaimCheck::ZeroHier::Val   Sub-claim 1_4   0.066667
# 149              ClaimCheck::ZeroHier::Val   Sub-claim 1_6   0.000000
# 150              ClaimCheck::ZeroHier::Val   Sub-claim 1_7   0.000000
# 151              ClaimCheck::ZeroHier::Val   Sub-claim 2_1   0.013699
# 152              ClaimCheck::ZeroHier::Val   Sub-claim 2_3   0.000000
# 153              ClaimCheck::ZeroHier::Val   Sub-claim 3_1   0.000000
# 154              ClaimCheck::ZeroHier::Val   Sub-claim 3_2   0.000000
# 155              ClaimCheck::ZeroHier::Val   Sub-claim 3_3   0.000000
# 156              ClaimCheck::ZeroHier::Val   Sub-claim 4_1   0.031250
# 157              ClaimCheck::ZeroHier::Val   Sub-claim 4_2   0.000000
# 158              ClaimCheck::ZeroHier::Val   Sub-claim 4_4   0.000000
# 159              ClaimCheck::ZeroHier::Val   Sub-claim 4_5   0.000000
# 160              ClaimCheck::ZeroHier::Val   Sub-claim 5_1   0.027027
# 161              ClaimCheck::ZeroHier::Val   Sub-claim 5_2   0.146341
#
#        Recall  F1 Score                  Support
# 0         NaN       NaN  2643/2701 (97.9% valid)
# 1    0.638668  0.638668                     None
# 2    0.695044  0.695044                     None
# 3    0.867630  0.867630                     None
# 4    0.479339  0.479339                     None
# 5    0.375000  0.375000                     None
# 6    0.394958  0.394958                     None
# 7    0.461538  0.461538                     None
# 8    0.148837  0.148837                     None
# 9    0.867630  0.867630                     None
# 10   0.166667  0.166667                     None
# 11   0.809524  0.809524                     None
# 12   0.666667  0.666667                     None
# 13   0.397059  0.397059                     None
# 14   0.666667  0.666667                     None
# 15   0.158730  0.158730                     None
# 16   0.286885  0.286885                     None
# 17   0.086957  0.086957                     None
# 18   0.120000  0.120000                     None
# 19   0.285714  0.285714                     None
# 20   0.088889  0.088889                     None
# 21   0.193548  0.193548                     None
# 22   0.382353  0.382353                     None
# 23   0.000000  0.000000                     None
# 24   0.085714  0.085714                     None
# 25   0.000000  0.000000                     None
# 26   0.138462  0.138462                     None
# 27        NaN       NaN  2550/2605 (97.9% valid)
# 28   0.642745  0.642745                     None
# 29   0.692549  0.692549                     None
# 30   0.827181  0.827181                     None
# 31   0.532609  0.532609                     None
# 32   0.403226  0.403226                     None
# 33   0.463158  0.463158                     None
# 34   0.460784  0.460784                     None
# 35   0.186770  0.186770                     None
# 36   0.827181  0.827181                     None
# 37   0.081081  0.081081                     None
# 38   0.625000  0.625000                     None
# 39   0.680000  0.680000                     None
# 40   0.346154  0.346154                     None
# 41   0.500000  0.500000                     None
# 42   0.272727  0.272727                     None
# 43   0.333333  0.333333                     None
# 44   0.108108  0.108108                     None
# 45   0.190476  0.190476                     None
# 46   0.315789  0.315789                     None
# 47   0.166667  0.166667                     None
# 48   0.285714  0.285714                     None
# 49   0.476190  0.476190                     None
# 50   0.000000  0.000000                     None
# 51   0.050000  0.050000                     None
# 52   0.013699  0.013699                     None
# 53   0.153153  0.153153                     None
# 54        NaN       NaN  2677/2904 (92.2% valid)
# 55   0.626074  0.626074                     None
# 56   0.677251  0.677251                     None
# 57   0.882006  0.882006                     None
# 58   0.488372  0.488372                     None
# 59   0.380952  0.380952                     None
# 60   0.383178  0.383178                     None
# 61   0.373333  0.373333                     None
# 62   0.165289  0.165289                     None
# 63   0.882006  0.882006                     None
# 64   0.190476  0.190476                     None
# 65   0.850000  0.850000                     None
# 66   0.714286  0.714286                     None
# 67   0.389831  0.389831                     None
# 68   0.571429  0.571429                     None
# 69   0.152542  0.152542                     None
# 70   0.225225  0.225225                     None
# 71   0.138889  0.138889                     None
# 72   0.136364  0.136364                     None
# 73   0.255814  0.255814                     None
# 74   0.119048  0.119048                     None
# 75   0.169811  0.169811                     None
# 76   0.322581  0.322581                     None
# 77   0.031250  0.031250                     None
# 78   0.117647  0.117647                     None
# 79   0.021390  0.021390                     None
# 80   0.130682  0.130682                     None
# 81        NaN       NaN  2390/2605 (91.7% valid)
# 82   0.671130  0.671130                     None
# 83   0.714644  0.714644                     None
# 84   0.854895  0.854895                     None
# 85   0.563636  0.563636                     None
# 86   0.420561  0.420561                     None
# 87   0.369048  0.369048                     None
# 88   0.391304  0.391304                     None
# 89   0.159292  0.159292                     None
# 90   0.854895  0.854895                     None
# 91   0.121212  0.121212                     None
# 92   0.625000  0.625000                     None
# 93   0.680000  0.680000                     None
# 94   0.409091  0.409091                     None
# 95   0.625000  0.625000                     None
# 96   0.230769  0.230769                     None
# 97   0.283951  0.283951                     None
# 98   0.153846  0.153846                     None
# 99   0.066667  0.066667                     None
# 100  0.277778  0.277778                     None
# 101  0.151515  0.151515                     None
# 102  0.258065  0.258065                     None
# 103  0.312500  0.312500                     None
# 104  0.000000  0.000000                     None
# 105  0.105263  0.105263                     None
# 106  0.015625  0.015625                     None
# 107  0.142857  0.142857                     None
# 108       NaN       NaN  2440/2904 (84.0% valid)
# 109  0.623361  0.623361                     None
# 110  0.633607  0.633607                     None
# 111  0.978934  0.978934                     None
# 112  0.041475  0.041475                     None
# 113  0.013245  0.013245                     None
# 114  0.009709  0.009709                     None
# 115  0.006897  0.006897                     None
# 116  0.150820  0.150820                     None
# 117  0.978934  0.978934                     None
# 118  0.000000  0.000000                     None
# 119  0.176471  0.176471                     None
# 120  0.000000  0.000000                     None
# 121  0.071429  0.071429                     None
# 122  0.000000  0.000000                     None
# 123  0.000000  0.000000                     None
# 124  0.000000  0.000000                     None
# 125  0.051282  0.051282                     None
# 126  0.000000  0.000000                     None
# 127  0.000000  0.000000                     None
# 128  0.000000  0.000000                     None
# 129  0.000000  0.000000                     None
# 130  0.000000  0.000000                     None
# 131  0.030303  0.030303                     None
# 132  0.000000  0.000000                     None
# 133  0.053254  0.053254                     None
# 134  0.110294  0.110294                     None
# 135       NaN       NaN  2161/2605 (83.0% valid)
# 136  0.702453  0.702453                     None
# 137  0.707543  0.707543                     None
# 138  0.975244  0.975244                     None
# 139  0.043210  0.043210                     None
# 140  0.009346  0.009346                     None
# 141  0.013514  0.013514                     None
# 142  0.011111  0.011111                     None
# 143  0.113990  0.113990                     None
# 144  0.975244  0.975244                     None
# 145  0.000000  0.000000                     None
# 146  0.066667  0.066667                     None
# 147  0.000000  0.000000                     None
# 148  0.066667  0.066667                     None
# 149  0.000000  0.000000                     None
# 150  0.000000  0.000000                     None
# 151  0.013699  0.013699                     None
# 152  0.000000  0.000000                     None
# 153  0.000000  0.000000                     None
# 154  0.000000  0.000000                     None
# 155  0.000000  0.000000                     None
# 156  0.031250  0.031250                     None
# 157  0.000000  0.000000                     None
# 158  0.000000  0.000000                     None
# 159  0.000000  0.000000                     None
# 160  0.027027  0.027027                     None
# 161  0.146341  0.146341                     None

# %%
combined_df[combined_df["Task"] == "ClaimCheck::ZeroFlat"][1:][["Task", "Category", "Precision", "Recall", "F1 Score"]]
# Out:
#                     Task        Category  Precision    Recall  F1 Score
# 1   ClaimCheck::ZeroFlat  All Sub-claims   0.638668  0.638668  0.638668
# 2   ClaimCheck::ZeroFlat      All Claims   0.695044  0.695044  0.695044
# 3   ClaimCheck::ZeroFlat         Claim 0   0.867630  0.867630  0.867630
# 4   ClaimCheck::ZeroFlat         Claim 1   0.479339  0.479339  0.479339
# 5   ClaimCheck::ZeroFlat         Claim 2   0.375000  0.375000  0.375000
# 6   ClaimCheck::ZeroFlat         Claim 3   0.394958  0.394958  0.394958
# 7   ClaimCheck::ZeroFlat         Claim 4   0.461538  0.461538  0.461538
# 8   ClaimCheck::ZeroFlat         Claim 5   0.148837  0.148837  0.148837
# 9   ClaimCheck::ZeroFlat   Sub-claim 0_0   0.867630  0.867630  0.867630
# 10  ClaimCheck::ZeroFlat   Sub-claim 1_1   0.166667  0.166667  0.166667
# 11  ClaimCheck::ZeroFlat   Sub-claim 1_2   0.809524  0.809524  0.809524
# 12  ClaimCheck::ZeroFlat   Sub-claim 1_3   0.666667  0.666667  0.666667
# 13  ClaimCheck::ZeroFlat   Sub-claim 1_4   0.397059  0.397059  0.397059
# 14  ClaimCheck::ZeroFlat   Sub-claim 1_6   0.666667  0.666667  0.666667
# 15  ClaimCheck::ZeroFlat   Sub-claim 1_7   0.158730  0.158730  0.158730
# 16  ClaimCheck::ZeroFlat   Sub-claim 2_1   0.286885  0.286885  0.286885
# 17  ClaimCheck::ZeroFlat   Sub-claim 2_3   0.086957  0.086957  0.086957
# 18  ClaimCheck::ZeroFlat   Sub-claim 3_1   0.120000  0.120000  0.120000
# 19  ClaimCheck::ZeroFlat   Sub-claim 3_2   0.285714  0.285714  0.285714
# 20  ClaimCheck::ZeroFlat   Sub-claim 3_3   0.088889  0.088889  0.088889
# 21  ClaimCheck::ZeroFlat   Sub-claim 4_1   0.193548  0.193548  0.193548
# 22  ClaimCheck::ZeroFlat   Sub-claim 4_2   0.382353  0.382353  0.382353
# 23  ClaimCheck::ZeroFlat   Sub-claim 4_4   0.000000  0.000000  0.000000
# 24  ClaimCheck::ZeroFlat   Sub-claim 4_5   0.085714  0.085714  0.085714
# 25  ClaimCheck::ZeroFlat   Sub-claim 5_1   0.000000  0.000000  0.000000
# 26  ClaimCheck::ZeroFlat   Sub-claim 5_2   0.138462  0.138462  0.138462

# %%
combined_df[combined_df["Task"] == "ClaimCheck::FewShotFlat::Similar"][1:][["Task", "Category", "Precision", "Recall", "F1 Score"]]
# Out:
#                                 Task        Category  Precision    Recall  \
# 55  ClaimCheck::FewShotFlat::Similar  All Sub-claims   0.626074  0.626074
# 56  ClaimCheck::FewShotFlat::Similar      All Claims   0.677251  0.677251
# 57  ClaimCheck::FewShotFlat::Similar         Claim 0   0.882006  0.882006
# 58  ClaimCheck::FewShotFlat::Similar         Claim 1   0.488372  0.488372
# 59  ClaimCheck::FewShotFlat::Similar         Claim 2   0.380952  0.380952
# 60  ClaimCheck::FewShotFlat::Similar         Claim 3   0.383178  0.383178
# 61  ClaimCheck::FewShotFlat::Similar         Claim 4   0.373333  0.373333
# 62  ClaimCheck::FewShotFlat::Similar         Claim 5   0.165289  0.165289
# 63  ClaimCheck::FewShotFlat::Similar   Sub-claim 0_0   0.882006  0.882006
# 64  ClaimCheck::FewShotFlat::Similar   Sub-claim 1_1   0.190476  0.190476
# 65  ClaimCheck::FewShotFlat::Similar   Sub-claim 1_2   0.850000  0.850000
# 66  ClaimCheck::FewShotFlat::Similar   Sub-claim 1_3   0.714286  0.714286
# 67  ClaimCheck::FewShotFlat::Similar   Sub-claim 1_4   0.389831  0.389831
# 68  ClaimCheck::FewShotFlat::Similar   Sub-claim 1_6   0.571429  0.571429
# 69  ClaimCheck::FewShotFlat::Similar   Sub-claim 1_7   0.152542  0.152542
# 70  ClaimCheck::FewShotFlat::Similar   Sub-claim 2_1   0.225225  0.225225
# 71  ClaimCheck::FewShotFlat::Similar   Sub-claim 2_3   0.138889  0.138889
# 72  ClaimCheck::FewShotFlat::Similar   Sub-claim 3_1   0.136364  0.136364
# 73  ClaimCheck::FewShotFlat::Similar   Sub-claim 3_2   0.255814  0.255814
# 74  ClaimCheck::FewShotFlat::Similar   Sub-claim 3_3   0.119048  0.119048
# 75  ClaimCheck::FewShotFlat::Similar   Sub-claim 4_1   0.169811  0.169811
# 76  ClaimCheck::FewShotFlat::Similar   Sub-claim 4_2   0.322581  0.322581
# 77  ClaimCheck::FewShotFlat::Similar   Sub-claim 4_4   0.031250  0.031250
# 78  ClaimCheck::FewShotFlat::Similar   Sub-claim 4_5   0.117647  0.117647
# 79  ClaimCheck::FewShotFlat::Similar   Sub-claim 5_1   0.021390  0.021390
# 80  ClaimCheck::FewShotFlat::Similar   Sub-claim 5_2   0.130682  0.130682
#
#     F1 Score
# 55  0.626074
# 56  0.677251
# 57  0.882006
# 58  0.488372
# 59  0.380952
# 60  0.383178
# 61  0.373333
# 62  0.165289
# 63  0.882006
# 64  0.190476
# 65  0.850000
# 66  0.714286
# 67  0.389831
# 68  0.571429
# 69  0.152542
# 70  0.225225
# 71  0.138889
# 72  0.136364
# 73  0.255814
# 74  0.119048
# 75  0.169811
# 76  0.322581
# 77  0.031250
# 78  0.117647
# 79  0.021390
# 80  0.130682

# %%
combined_df[combined_df["Task"] == "ClaimCheck::ZeroHier"][1:][["Task", "Category", "Precision", "Recall", "F1 Score"]]
# Out:
#                      Task        Category  Precision    Recall  F1 Score
# 109  ClaimCheck::ZeroHier  All Sub-claims   0.623361  0.623361  0.623361
# 110  ClaimCheck::ZeroHier      All Claims   0.633607  0.633607  0.633607
# 111  ClaimCheck::ZeroHier         Claim 0   0.978934  0.978934  0.978934
# 112  ClaimCheck::ZeroHier         Claim 1   0.041475  0.041475  0.041475
# 113  ClaimCheck::ZeroHier         Claim 2   0.013245  0.013245  0.013245
# 114  ClaimCheck::ZeroHier         Claim 3   0.009709  0.009709  0.009709
# 115  ClaimCheck::ZeroHier         Claim 4   0.006897  0.006897  0.006897
# 116  ClaimCheck::ZeroHier         Claim 5   0.150820  0.150820  0.150820
# 117  ClaimCheck::ZeroHier   Sub-claim 0_0   0.978934  0.978934  0.978934
# 118  ClaimCheck::ZeroHier   Sub-claim 1_1   0.000000  0.000000  0.000000
# 119  ClaimCheck::ZeroHier   Sub-claim 1_2   0.176471  0.176471  0.176471
# 120  ClaimCheck::ZeroHier   Sub-claim 1_3   0.000000  0.000000  0.000000
# 121  ClaimCheck::ZeroHier   Sub-claim 1_4   0.071429  0.071429  0.071429
# 122  ClaimCheck::ZeroHier   Sub-claim 1_6   0.000000  0.000000  0.000000
# 123  ClaimCheck::ZeroHier   Sub-claim 1_7   0.000000  0.000000  0.000000
# 124  ClaimCheck::ZeroHier   Sub-claim 2_1   0.000000  0.000000  0.000000
# 125  ClaimCheck::ZeroHier   Sub-claim 2_3   0.051282  0.051282  0.051282
# 126  ClaimCheck::ZeroHier   Sub-claim 3_1   0.000000  0.000000  0.000000
# 127  ClaimCheck::ZeroHier   Sub-claim 3_2   0.000000  0.000000  0.000000
# 128  ClaimCheck::ZeroHier   Sub-claim 3_3   0.000000  0.000000  0.000000
# 129  ClaimCheck::ZeroHier   Sub-claim 4_1   0.000000  0.000000  0.000000
# 130  ClaimCheck::ZeroHier   Sub-claim 4_2   0.000000  0.000000  0.000000
# 131  ClaimCheck::ZeroHier   Sub-claim 4_4   0.030303  0.030303  0.030303
# 132  ClaimCheck::ZeroHier   Sub-claim 4_5   0.000000  0.000000  0.000000
# 133  ClaimCheck::ZeroHier   Sub-claim 5_1   0.053254  0.053254  0.053254
# 134  ClaimCheck::ZeroHier   Sub-claim 5_2   0.110294  0.110294  0.110294

# %%
# %matplotlib notebook

# %%
! pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /apps/Arch/software/SciPy-bundle/2023.07-gfbf-2023a/lib/python3.11/site-packages (from seaborn) (1.25.1)
# Requirement already satisfied: pandas>=1.2 in /apps/Arch/software/SciPy-bundle/2023.07-gfbf-2023a/lib/python3.11/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /apps/Arch/software/matplotlib/3.7.2-gfbf-2023a/lib/python3.11/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /apps/Arch/software/matplotlib/3.7.2-gfbf-2023a/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /apps/Arch/software/matplotlib/3.7.2-gfbf-2023a/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /apps/Arch/software/matplotlib/3.7.2-gfbf-2023a/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /apps/Arch/software/matplotlib/3.7.2-gfbf-2023a/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /apps/Arch/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /apps/Arch/software/Pillow-SIMD/9.5.0-GCCcore-12.3.0/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing<=3.1,>=2.3.1 in /apps/Arch/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /apps/Arch/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /apps/Arch/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /apps/Arch/software/SciPy-bundle/2023.07-gfbf-2023a/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /apps/Arch/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
for task_config in configs_list:
    result_dir = task_config.result_dir.format("val" if task_config.val_mode else "test") 
    result_path = f"{result_dir}/{task_config.id}.csv"
    df = pd.read_csv(result_path)

    df[['true_claim', 'true_subclaim']] = df['sub_claim_code'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))
    df[['pred_claim', 'pred_subclaim']] = df['prediction'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))


    df =  df[(df['pred_subclaim'] != -1) & (df['true_subclaim'] != -1)]    
    df =  df[(df['pred_subclaim'] != "0_0") & (df['true_subclaim'] != "0_0")]

    true_claim_labels = df['true_claim']
    pred_claim_labels = df['pred_claim']

    true_subclaim_labels = df['true_subclaim']
    pred_subclaim_labels = df['pred_subclaim']

    ## Claims 
    claim_labels = sorted(list(set(true_claim_labels) | set(pred_claim_labels)))
    cm_1 = confusion_matrix(true_claim_labels, pred_claim_labels, labels=claim_labels)

    plt.figure(figsize=(14, 10))
    sns.heatmap(cm_1, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=claim_labels, yticklabels=claim_labels)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.title('Normalized Confusion Matrix')
    plt.savefig(f"results/images/confusion_matrix_claim_{task_config.id}.png", dpi=300, bbox_inches='tight')

    ## Sub_Claims 
    subclaim_labels = sorted(list(set(true_subclaim_labels) | set(pred_subclaim_labels)))
    cm_2 = confusion_matrix(true_subclaim_labels, pred_subclaim_labels, labels=subclaim_labels)

    plt.figure(figsize=(24, 20))
    sns.heatmap(cm_2, annot=True, cmap="Blues",
                xticklabels=subclaim_labels, yticklabels=subclaim_labels)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.title('Normalized Confusion Matrix')
    plt.savefig(f"results/images/confusion_matrix_subclaim_{task_config.id}.png", dpi=300, bbox_inches='tight')
# Out:
# <div id='36a7c078-8cbc-40cd-9ba2-33ecede3beae'></div>
# <div id='c9874e9c-4c56-4638-9808-b263c0eaf989'></div>
# <div id='c7ba59cf-a8fc-408a-98be-229d10e16f8a'></div>
# <div id='82c9d6d1-4ea7-48cd-b47a-63fb1067225d'></div>
# <div id='ea7f401f-6c67-413a-ad25-ce3589387290'></div>
# <div id='aae13192-1220-40cf-ac48-5a21019c9ed3'></div>
# <div id='c4c9fecf-d0f2-4ab9-b409-0cebeaea076e'></div>
# <div id='7b0608a4-55c5-4e1e-b09e-97b6c4954400'></div>
# <div id='06a62a92-c328-40b6-b8cb-e8941a0b63d2'></div>
# <div id='1ea1cf27-b08f-405f-a014-56525b049873'></div>
# <div id='6b4ef787-0377-4cc9-b303-8d820ce51f25'></div>
# <div id='2ea7e1e3-2bb5-4a4a-a56c-49ac0ed95219'></div>

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Blues",
            xticklabels=claim_labels, yticklabels=claim_labels)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Normalized Confusion Matrix')
plt.show()
# Out:
# <div id='233d588e-ccaf-44b6-b1e6-a98e95669a67'></div>

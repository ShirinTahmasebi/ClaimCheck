# %%
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# %%
from task_config import ZeroFlatConfig1, ZeroFlatConfig2, FewFlatConfig1, FewFlatConfig2
configs_list = [ZeroFlatConfig1, ZeroFlatConfig2, FewFlatConfig1, FewFlatConfig2]

# %%
def extract_claim_subclaim(code):
    if pd.isna(code) or code == '-1':
        return -1, -1
    try:
        claim, _ = map(int, code.split('_'))
        return claim, code
    except Exception:
        return -1, -1

# %%
def calculate_metrics(y_true, y_pred):
    labels = sorted(set(y_true) | set(y_pred))
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true, y_pred, labels=labels, average='macro', zero_division=0
    )
    # print(f"Precision: {precision:.3f} | Recall: {recall:.3f} | F1 Score: {f1:.3f}")
    return precision, recall, f1

# %%
def evaluate_predictions(df):
    metrics = []

    df[['true_claim', 'true_subclaim']] = df['sub_claim_code'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))
    df[['pred_claim', 'pred_subclaim']] = df['prediction'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))

    total = len(df)
    invalid = len(df[df['pred_subclaim'] == -1])
    valid = total - invalid
    
    metrics.append({
        "Category": "Summary",
        "Precision": None,
        "Recall": None,
        "F1 Score": None,
        "Support": f"{valid}/{total} ({valid / total:.1%} valid)"
    })

    # Filter valid examples only
    valid_df = df[(df['pred_subclaim'] != -1) & (df['true_subclaim'] != -1)]

    # ---------- Overall Metrics ----------
    precision, recall, f1 = calculate_metrics(valid_df['true_subclaim'], valid_df['pred_subclaim'])
    metrics.append({
            "Category": "All Sub-claims",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
    })

    # print("\n--- Overall Claim Classification ---")
    precision, recall, f1 = calculate_metrics(valid_df['true_claim'], valid_df['pred_claim'])
    metrics.append({
            "Category": "All Claims",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
    })

    # ---------- Per-Claim Category ----------
    for claim in sorted(valid_df['true_claim'].unique()):
        subset = valid_df[valid_df['true_claim'] == claim]
        precision, recall, f1 = calculate_metrics(subset['true_claim'], subset['pred_claim'])
        metrics.append({
            "Category": f"Claim {claim}",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
        })

    # ---------- Per Sub-Claim Category ----------
    for subclaim in sorted(valid_df['true_subclaim'].unique()):
        subset = valid_df[valid_df['true_subclaim'] == subclaim]
        calculate_metrics(subset['true_subclaim'], subset['pred_subclaim'])
        metrics.append({
            "Category": f"Sub-claim {subclaim}",
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Support": None
        })

    return pd.DataFrame(metrics)

# %%
def print_statistics(df):

    df[['true_claim', 'true_subclaim']] = df['sub_claim_code'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))
    df[['pred_claim', 'pred_subclaim']] = df['prediction'].apply(lambda x: pd.Series(extract_claim_subclaim(x)))

    total = len(df)
    invalid = len(df[df['pred_subclaim'] == -1])
    valid = total - invalid
    
    valid_df = df[(df['pred_subclaim'] != -1) & (df['true_subclaim'] != -1)]

    for claim in sorted(valid_df['true_claim'].unique()):
        subset = valid_df[valid_df['true_claim'] == claim]
        print(f"Claim: {claim}: {len(subset)}")
        
    for subclaim in sorted(valid_df['true_subclaim'].unique()):
        subset = valid_df[valid_df['true_subclaim'] == subclaim]
        print(f"Sublaim: {subclaim}: {len(subset)}")

# %%
combined_df = None
printed_stats_test = False
printed_stats_val = False

for task_config in configs_list:
    result_dir = task_config.result_dir.format("val" if task_config.val_mode else "test") 
    result_path = f"{result_dir}/{task_config.id}.csv"
    if task_config.val_mode and not printed_stats_val:
        print_statistics(df)
        printed_stats_val = True
    if not task_config.val_mode and not printed_stats_test:
        print_statistics(df)
        printed_stats_test = True
    df = pd.read_csv(result_path)
    metrics_df = evaluate_predictions(df)
    metrics_df.insert(0, 'Task', task_config.name)
    if combined_df is None:
        combined_df = metrics_df
    else:
        combined_df = pd.concat([combined_df, metrics_df], ignore_index=True)
# Out:
# Claim: 0: 627
# Claim: 1: 62
# Claim: 2: 52
# Claim: 3: 31
# Claim: 4: 25
# Claim: 5: 73
# Sublaim: 0_0: 627
# Sublaim: 1_1: 13
# Sublaim: 1_2: 4
# Sublaim: 1_3: 12
# Sublaim: 1_4: 20
# Sublaim: 1_6: 3
# Sublaim: 1_7: 10
# Sublaim: 2_1: 41
# Sublaim: 2_3: 11
# Sublaim: 3_1: 6
# Sublaim: 3_2: 12
# Sublaim: 3_3: 13
# Sublaim: 4_1: 7
# Sublaim: 4_2: 7
# Sublaim: 4_4: 5
# Sublaim: 4_5: 6
# Sublaim: 5_1: 43
# Sublaim: 5_2: 30
# Claim: 0: 1730
# Claim: 1: 242
# Claim: 2: 168
# Claim: 3: 119
# Claim: 4: 169
# Claim: 5: 215
# Sublaim: 0_0: 1730
# Sublaim: 1_1: 48
# Sublaim: 1_2: 21
# Sublaim: 1_3: 30
# Sublaim: 1_4: 68
# Sublaim: 1_6: 12
# Sublaim: 1_7: 63
# Sublaim: 2_1: 122
# Sublaim: 2_3: 46
# Sublaim: 3_1: 25
# Sublaim: 3_2: 49
# Sublaim: 3_3: 45
# Sublaim: 4_1: 62
# Sublaim: 4_2: 34
# Sublaim: 4_4: 38
# Sublaim: 4_5: 35
# Sublaim: 5_1: 150
# Sublaim: 5_2: 65

# %%
import pandas as pd

# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)

combined_df.head(len(combined_df))
# Out:
#                                        Task        Category  Precision  \
# 0                ClaimCheck::ZeroFlat::Test         Summary        NaN
# 1                ClaimCheck::ZeroFlat::Test  All Sub-claims   0.314758
# 2                ClaimCheck::ZeroFlat::Test      All Claims   0.497916
# 3                ClaimCheck::ZeroFlat::Test         Claim 0   0.166667
# 4                ClaimCheck::ZeroFlat::Test         Claim 1   0.166667
# 5                ClaimCheck::ZeroFlat::Test         Claim 2   0.200000
# 6                ClaimCheck::ZeroFlat::Test         Claim 3   0.166667
# 7                ClaimCheck::ZeroFlat::Test         Claim 4   0.250000
# 8                ClaimCheck::ZeroFlat::Test         Claim 5   0.166667
# 9                ClaimCheck::ZeroFlat::Test   Sub-claim 0_0   0.166667
# 10               ClaimCheck::ZeroFlat::Test   Sub-claim 1_1   0.166667
# 11               ClaimCheck::ZeroFlat::Test   Sub-claim 1_2   0.166667
# 12               ClaimCheck::ZeroFlat::Test   Sub-claim 1_3   0.166667
# 13               ClaimCheck::ZeroFlat::Test   Sub-claim 1_4   0.166667
# 14               ClaimCheck::ZeroFlat::Test   Sub-claim 1_6   0.166667
# 15               ClaimCheck::ZeroFlat::Test   Sub-claim 1_7   0.166667
# 16               ClaimCheck::ZeroFlat::Test   Sub-claim 2_1   0.166667
# 17               ClaimCheck::ZeroFlat::Test   Sub-claim 2_3   0.166667
# 18               ClaimCheck::ZeroFlat::Test   Sub-claim 3_1   0.166667
# 19               ClaimCheck::ZeroFlat::Test   Sub-claim 3_2   0.166667
# 20               ClaimCheck::ZeroFlat::Test   Sub-claim 3_3   0.166667
# 21               ClaimCheck::ZeroFlat::Test   Sub-claim 4_1   0.166667
# 22               ClaimCheck::ZeroFlat::Test   Sub-claim 4_2   0.166667
# 23               ClaimCheck::ZeroFlat::Test   Sub-claim 4_4   0.166667
# 24               ClaimCheck::ZeroFlat::Test   Sub-claim 4_5   0.166667
# 25               ClaimCheck::ZeroFlat::Test   Sub-claim 5_1   0.166667
# 26               ClaimCheck::ZeroFlat::Test   Sub-claim 5_2   0.166667
# 27                ClaimCheck::ZeroFlat::Val         Summary        NaN
# 28                ClaimCheck::ZeroFlat::Val  All Sub-claims   0.328302
# 29                ClaimCheck::ZeroFlat::Val      All Claims   0.464135
# 30                ClaimCheck::ZeroFlat::Val         Claim 0   0.166667
# 31                ClaimCheck::ZeroFlat::Val         Claim 1   0.166667
# 32                ClaimCheck::ZeroFlat::Val         Claim 2   0.250000
# 33                ClaimCheck::ZeroFlat::Val         Claim 3   0.250000
# 34                ClaimCheck::ZeroFlat::Val         Claim 4   0.250000
# 35                ClaimCheck::ZeroFlat::Val         Claim 5   0.166667
# 36                ClaimCheck::ZeroFlat::Val   Sub-claim 0_0   0.166667
# 37                ClaimCheck::ZeroFlat::Val   Sub-claim 1_1   0.166667
# 38                ClaimCheck::ZeroFlat::Val   Sub-claim 1_2   0.166667
# 39                ClaimCheck::ZeroFlat::Val   Sub-claim 1_3   0.166667
# 40                ClaimCheck::ZeroFlat::Val   Sub-claim 1_4   0.166667
# 41                ClaimCheck::ZeroFlat::Val   Sub-claim 1_6   0.166667
# 42                ClaimCheck::ZeroFlat::Val   Sub-claim 1_7   0.166667
# 43                ClaimCheck::ZeroFlat::Val   Sub-claim 2_1   0.166667
# 44                ClaimCheck::ZeroFlat::Val   Sub-claim 2_3   0.166667
# 45                ClaimCheck::ZeroFlat::Val   Sub-claim 3_1   0.166667
# 46                ClaimCheck::ZeroFlat::Val   Sub-claim 3_2   0.166667
# 47                ClaimCheck::ZeroFlat::Val   Sub-claim 3_3   0.166667
# 48                ClaimCheck::ZeroFlat::Val   Sub-claim 4_1   0.166667
# 49                ClaimCheck::ZeroFlat::Val   Sub-claim 4_2   0.166667
# 50                ClaimCheck::ZeroFlat::Val   Sub-claim 4_4   0.166667
# 51                ClaimCheck::ZeroFlat::Val   Sub-claim 4_5   0.166667
# 52                ClaimCheck::ZeroFlat::Val   Sub-claim 5_1   0.166667
# 53                ClaimCheck::ZeroFlat::Val   Sub-claim 5_2   0.166667
# 54   ClaimCheck::FewShotFlat::Similar::Test         Summary        NaN
# 55   ClaimCheck::FewShotFlat::Similar::Test  All Sub-claims   0.156044
# 56   ClaimCheck::FewShotFlat::Similar::Test      All Claims   0.292192
# 57   ClaimCheck::FewShotFlat::Similar::Test         Claim 0   0.166667
# 58   ClaimCheck::FewShotFlat::Similar::Test         Claim 1   0.333333
# 59   ClaimCheck::FewShotFlat::Similar::Test         Claim 2   0.333333
# 60   ClaimCheck::FewShotFlat::Similar::Test         Claim 3   0.333333
# 61   ClaimCheck::FewShotFlat::Similar::Test         Claim 4   0.333333
# 62   ClaimCheck::FewShotFlat::Similar::Test         Claim 5   0.166667
# 63   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 0_0   0.166667
# 64   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 1_1   0.166667
# 65   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 1_3   0.166667
# 66   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 1_4   0.166667
# 67   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 1_7   0.166667
# 68   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 2_1   0.166667
# 69   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 2_3   0.166667
# 70   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 3_1   0.166667
# 71   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 3_2   0.166667
# 72   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 3_3   0.166667
# 73   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 4_1   0.166667
# 74   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 4_2   0.166667
# 75   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 4_4   0.166667
# 76   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 4_5   0.166667
# 77   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 5_1   0.166667
# 78   ClaimCheck::FewShotFlat::Similar::Test   Sub-claim 5_2   0.166667
# 79    ClaimCheck::FewShotFlat::Similar::Val         Summary        NaN
# 80    ClaimCheck::FewShotFlat::Similar::Val  All Sub-claims   0.242580
# 81    ClaimCheck::FewShotFlat::Similar::Val      All Claims   0.444784
# 82    ClaimCheck::FewShotFlat::Similar::Val         Claim 0   0.166667
# 83    ClaimCheck::FewShotFlat::Similar::Val         Claim 1   0.200000
# 84    ClaimCheck::FewShotFlat::Similar::Val         Claim 2   0.200000
# 85    ClaimCheck::FewShotFlat::Similar::Val         Claim 3   0.250000
# 86    ClaimCheck::FewShotFlat::Similar::Val         Claim 4   0.250000
# 87    ClaimCheck::FewShotFlat::Similar::Val         Claim 5   0.166667
# 88    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 0_0   0.166667
# 89    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_1   0.166667
# 90    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_2   0.166667
# 91    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_3   0.166667
# 92    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_4   0.166667
# 93    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_6   0.166667
# 94    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 1_7   0.166667
# 95    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 2_1   0.166667
# 96    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 2_3   0.166667
# 97    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 3_1   0.166667
# 98    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 3_2   0.166667
# 99    ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 3_3   0.166667
# 100   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_1   0.166667
# 101   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_2   0.166667
# 102   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_4   0.166667
# 103   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 4_5   0.166667
# 104   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 5_1   0.166667
# 105   ClaimCheck::FewShotFlat::Similar::Val   Sub-claim 5_2   0.166667
#
#        Recall  F1 Score                  Support
# 0         NaN       NaN  2643/2701 (97.9% valid)
# 1    0.300081  0.262905                     None
# 2    0.454550  0.453625                     None
# 3    0.144605  0.154854                     None
# 4    0.079890  0.108007                     None
# 5    0.075000  0.109091                     None
# 6    0.065826  0.094378                     None
# 7    0.115385  0.157895                     None
# 8    0.024806  0.043185                     None
# 9    0.024806  0.043185                     None
# 10   0.024806  0.043185                     None
# 11   0.024806  0.043185                     None
# 12   0.024806  0.043185                     None
# 13   0.024806  0.043185                     None
# 14   0.024806  0.043185                     None
# 15   0.024806  0.043185                     None
# 16   0.024806  0.043185                     None
# 17   0.024806  0.043185                     None
# 18   0.024806  0.043185                     None
# 19   0.024806  0.043185                     None
# 20   0.024806  0.043185                     None
# 21   0.024806  0.043185                     None
# 22   0.024806  0.043185                     None
# 23   0.024806  0.043185                     None
# 24   0.024806  0.043185                     None
# 25   0.024806  0.043185                     None
# 26   0.024806  0.043185                     None
# 27        NaN       NaN  2550/2605 (97.9% valid)
# 28   0.301404  0.256705                     None
# 29   0.478955  0.445139                     None
# 30   0.137864  0.150903                     None
# 31   0.088768  0.115839                     None
# 32   0.100806  0.143678                     None
# 33   0.115789  0.158273                     None
# 34   0.115196  0.157718                     None
# 35   0.031128  0.052459                     None
# 36   0.031128  0.052459                     None
# 37   0.031128  0.052459                     None
# 38   0.031128  0.052459                     None
# 39   0.031128  0.052459                     None
# 40   0.031128  0.052459                     None
# 41   0.031128  0.052459                     None
# 42   0.031128  0.052459                     None
# 43   0.031128  0.052459                     None
# 44   0.031128  0.052459                     None
# 45   0.031128  0.052459                     None
# 46   0.031128  0.052459                     None
# 47   0.031128  0.052459                     None
# 48   0.031128  0.052459                     None
# 49   0.031128  0.052459                     None
# 50   0.031128  0.052459                     None
# 51   0.031128  0.052459                     None
# 52   0.031128  0.052459                     None
# 53   0.031128  0.052459                     None
# 54        NaN       NaN  1206/1281 (94.1% valid)
# 55   0.240546  0.177048                     None
# 56   0.399924  0.297069                     None
# 57   0.142770  0.153795                     None
# 58   0.166667  0.222222                     None
# 59   0.083333  0.133333                     None
# 60   0.111111  0.166667                     None
# 61   0.092593  0.144928                     None
# 62   0.030303  0.051282                     None
# 63   0.030303  0.051282                     None
# 64   0.030303  0.051282                     None
# 65   0.030303  0.051282                     None
# 66   0.030303  0.051282                     None
# 67   0.030303  0.051282                     None
# 68   0.030303  0.051282                     None
# 69   0.030303  0.051282                     None
# 70   0.030303  0.051282                     None
# 71   0.030303  0.051282                     None
# 72   0.030303  0.051282                     None
# 73   0.030303  0.051282                     None
# 74   0.030303  0.051282                     None
# 75   0.030303  0.051282                     None
# 76   0.030303  0.051282                     None
# 77   0.030303  0.051282                     None
# 78   0.030303  0.051282                     None
# 79        NaN       NaN    870/951 (91.5% valid)
# 80   0.229587  0.199642                     None
# 81   0.438116  0.414375                     None
# 82   0.141414  0.153005                     None
# 83   0.103226  0.136170                     None
# 84   0.084615  0.118919                     None
# 85   0.072581  0.112500                     None
# 86   0.100000  0.142857                     None
# 87   0.025114  0.043651                     None
# 88   0.025114  0.043651                     None
# 89   0.025114  0.043651                     None
# 90   0.025114  0.043651                     None
# 91   0.025114  0.043651                     None
# 92   0.025114  0.043651                     None
# 93   0.025114  0.043651                     None
# 94   0.025114  0.043651                     None
# 95   0.025114  0.043651                     None
# 96   0.025114  0.043651                     None
# 97   0.025114  0.043651                     None
# 98   0.025114  0.043651                     None
# 99   0.025114  0.043651                     None
# 100  0.025114  0.043651                     None
# 101  0.025114  0.043651                     None
# 102  0.025114  0.043651                     None
# 103  0.025114  0.043651                     None
# 104  0.025114  0.043651                     None
# 105  0.025114  0.043651                     None
